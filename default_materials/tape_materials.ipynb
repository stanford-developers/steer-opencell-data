# %%
from steer_core.Data.DataManager import DataManager
from steer_opencell_design import TapeMaterial
from steer_materials import __version__
import pandas as pd

# %%
db = DataManager()

# %%
db.get_table_names()
# Out:
# ['anode_materials',
#  'binder_materials',
#  'cathode_materials',
#  'conductive_additive_materials',
#  'current_collector_materials',
#  'insulation_materials',
#  'prismatic_container_materials',
#  'separator_materials']

# %%
db.drop_table('tape_materials')

# %%
db.create_table(table_name='tape_materials', columns={
    'name': 'TEXT',
    'object': 'TEXT',
    'date': 'TEXT',
    'version': 'TEXT'
})

# %%
# materials 

kapton = TapeMaterial(
    name="Kapton",
    density=1.42,
    specific_cost=70.0,
    color="#C9641F",
)

polyester = TapeMaterial(
    name="Polyester",
    density=1.38,
    specific_cost=8.0,
    color="#DCE2E8",
)

# %%
materials = [
    kapton,
    polyester,
]

pickled_materials = [m.serialize() for m in materials]

# %%
# store data for current collectors

db.insert_data(table_name='tape_materials', data=pd.DataFrame({
    'name': [m.name for m in materials],
    'object': pickled_materials,
    'date': [m.last_updated for m in materials],
    'version': [__version__ for m in materials],
}))

# %%
db.get_tape_materials(most_recent=False)
# Out:
#         name                                             object  \
# 0     Kapton  b"\x01x\x9c\xebZ\x11\x9f\x92\x9aW\x9cYRy\xdaa\...
# 1  Polyester  b"\x01x\x9c\xebZ\x11\x9f\x92\x9aW\x9cYRy\xdaaj...
#
#                   date version
# 0  2025-12-13 14:15:13  0.1.17
# 1  2025-12-13 14:15:13  0.1.17
