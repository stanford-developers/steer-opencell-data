# %%
from steer_core.DataManager import DataManager
from steer_materials.CellMaterials.Base import TapeMaterial
from steer_materials import __version__
from datetime import datetime as dt
import pandas as pd

# %%
db = DataManager()

# %%
db.get_table_names()
# Out:
# ['cells',
#  'anode_materials',
#  'binder_materials',
#  'cathode_materials',
#  'conductive_additive_materials',
#  'current_collector_materials',
#  'insulation_materials',
#  'separator_materials',
#  'tape_materials']

# %%
db.drop_table('tape_materials')

# %%
db.create_table(table_name='tape_materials', columns={
    'name': 'TEXT',
    'object': 'TEXT',
    'date': 'TEXT',
    'version': 'TEXT'
})

# %%
# materials 

kapton = TapeMaterial(
    name="Kapton",
    density=1.42,
    specific_cost=70.0,
    color="#C9641F",
)

polyester = TapeMaterial(
    name="Polyester",
    density=1.38,
    specific_cost=8.0,
    color="#DCE2E8",
)

# %%
materials = [
    kapton,
    polyester,
]

pickled_materials = [m.serialize() for m in materials]

# %%
# store data for current collectors

db.insert_data(table_name='tape_materials', data=pd.DataFrame({
    'name': [m.name for m in materials],
    'object': pickled_materials,
    'date': [m.last_updated for m in materials],
    'version': [__version__ for m in materials],
}))

# %%
db.get_tape_materials(most_recent=False)
# Out:
#         name                                             object  \
# 0     Kapton  gASVGgEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
# 1  Polyester  gASVHQEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
#
#                   date version
# 0  2025-11-12 15:34:28  0.1.13
# 1  2025-11-12 15:34:28  0.1.13
